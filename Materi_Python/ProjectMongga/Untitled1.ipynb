# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %%
df[["Attack","HP"]].iloc[90:100]
# Out:
#     Attack   HP
# 90      65   52
# 91      85   35
# 92     110   60
# 93      45   65
# 94      70   90
# 95      80   80
# 96     105  105
# 97      65   30
# 98      95   50
# 99      35   30

# %%
df.iloc[90:100,1:3]
# Out:
#           Name  Type 1
# 90  Farfetch'd  Normal
# 91       Doduo  Normal
# 92      Dodrio  Normal
# 93        Seel   Water
# 94     Dewgong   Water
# 95      Grimer  Poison
# 96         Muk  Poison
# 97    Shellder   Water
# 98    Cloyster   Water
# 99      Gastly   Ghost

# %%
df.loc[(df["Type 1"]=="Water") & ((df["HP"]>50) | (df["HP"]<40))]
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 10     8                Wartortle  Water       NaN  59      63       80
# 11     9                Blastoise  Water       NaN  79      83      100
# 12     9  BlastoiseMega Blastoise  Water       NaN  79     103      120
# 60    55                  Golduck  Water       NaN  80      82       78
# 66    61                Poliwhirl  Water       NaN  65      65       65
# ..   ...                      ...    ...       ...  ..     ...      ...
# 713  647     KeldeoOrdinary Forme  Water  Fighting  91      72       90
# 714  647     KeldeoResolute Forme  Water  Fighting  91      72       90
# 725  657                Frogadier  Water       NaN  54      63       52
# 726  658                 Greninja  Water      Dark  72      95       67
# 763  693                Clawitzer  Water       NaN  71      73       88
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df["Strength"] = df["HP"] + df["Attack"]+df["Defense"]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Strength
# 0       65     45           1      False       143
# 1       80     60           1      False       185
# 2      100     80           1      False       245
# 3      120     80           1      False       303
# 4       50     65           1      False       134

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Strength'],
#       dtype='object')

# %%
df.drop(columns = ["Strength"])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df["Strength"] = df["HP"] + df["Attack"]+df["Defense"]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Strength
# 0         65       65     45           1      False       143
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Strength'],
#       dtype='object')

# %%
kolom = list(df.columns)

# %%
df = df[kolom[:4]+[kolom[-1]]+kolom[4:-1]]

# %%
df2 = df[["Name","Type 1","Type 2","Strength"]]

# %%
df["Spesial"] = False

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Strength  Spesial
# ...

# %%
df["Spesial"].iloc[100] = [True]

# %%
df["Spesial"].iloc[100]
# Out:
# True

# %%
df.loc[(df["Type 1"]=="Water") & ((df["HP"]>50)),["Spesial","Legendary"]]=[True,"Tesmas"]

# %%
df.iloc[7:15]
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN  79     103      120
# 13  10                   Caterpie    Bug     NaN  45      30       35
# 14  11                    Metapod    Bug     NaN  50      20       55
#
#     Sp. Atk  Sp. Def  Speed  Generation Legendary  Strength  Spesial
# 7       130       85    100           1     False       319    False
# 8       159      115    100           1     False       260    False
# 9        50       64     43           1     False       157    False
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation    Strength
# count  800.000000   800.00000  800.000000
# mean    68.277500     3.32375  222.102500
# std     29.060474     1.66129   68.173834
# min      5.000000     1.00000   55.000000
# 25%     45.000000     2.00000  170.000000
# ...

# %%
df["count"] = 1

# %%
df=df.drop(columns=["Strength","Spesial"])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation Legendary  count
# 0         65       65     45           1     False      1
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation  count
# count  800.000000   800.00000  800.0
# mean    68.277500     3.32375    1.0
# std     29.060474     1.66129    0.0
# min      5.000000     1.00000    1.0
# 25%     45.000000     2.00000    1.0
# 50%     65.000000     3.00000    1.0
# ...

# %%
df.groupby(["Legendary","Type 1"]).mean()
# Out:
#                              #          HP      Attack     Defense  \
# Legendary Type 1
# False     Bug       334.492754   56.884058   70.971014   70.724638
#           Dark      451.517241   64.655172   86.862069   68.689655
#           Dragon    447.350000   72.650000  103.400000   78.150000
#           Electric  358.050000   57.325000   66.125000   65.425000
#           Fairy     432.875000   70.875000   57.187500   63.875000
#           Fighting  363.851852   69.851852   96.777778   65.925926
#           Fire      322.957447   67.085106   82.191489   64.531915
#           Flying    714.500000   62.500000   50.000000   57.500000
#           Ghost     486.466667   58.733333   71.366667   79.266667
#           Grass     336.074627   65.940299   72.119403   70.283582
#           Ground    333.750000   70.821429   88.000000   79.821429
#           Ice       438.318182   70.818182   73.227273   68.818182
#           Normal    315.625000   76.489583   72.083333   58.697917
# ...

# %%
df.to_csv("data_baru.csv",index=False)
